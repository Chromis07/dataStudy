# %% [markdown]
# <a href="https://colab.research.google.com/github/Chromis07/dataStudy/blob/main/ML/Keras/tensorflow(%EC%83%9D%ED%99%9C%EC%BD%94%EB%94%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 준비하기 1
#
# 1. 데이터를 불러온다
# 2. 종속변수와 독립변수로 분리한다.
#
# - 실습을 통해 배울 도구들
#   - 파일 읽어오기: **read_csv('/경로/파일명.csv')**
#   - 모양 확인하기: **데이터.shape**
#   - 칼럼 선택하기: **데이터[['칼럼명1', '칼럼명2', '칼럼명3']]**
#   - 칼럼 이름 출력하기: **데이터.columns**
#   - 맨 위 5개 관측치 출력하기: **데이터.head()**
#
# - 샘플 데이터
#   - GitHub github link: https://github.com/blackdew/tensorflow1/tree/master/csv
#   - 레모네이드: https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv
#   - 보스톤: https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv
#   - 아이리스: https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv

# %%
import pandas as pd

# %%
# 데이터 읽어오기
dir = "https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv"
lemonade = pd.read_csv(dir)

dir = "https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv"
boston = pd.read_csv(dir)

dir = "https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv"
iris = pd.read_csv(dir)

# %%
# 데이터 모양으로 확인
print(lemonade.shape)
print(boston.shape)
print(iris.shape)
# Out:
# (6, 2)
# (506, 14)
# (150, 5)

# %%
# 칼럼 이름 출력
print(lemonade.columns)
print(boston.columns)
print(iris.columns)
# Out:
# Index(['온도', '판매량'], dtype='object')
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')
# Index(['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭', '품종'], dtype='object')

# %%
X = lemonade[['온도']]
y = lemonade[['판매량']]
print(X.shape, y.shape)
# Out:
# (6, 1) (6, 1)

# %%
X = boston[boston.columns[:-1]]
y = boston[['medv']]
print(X.shape, y.shape)
# Out:
# (506, 13) (506, 1)

# %%
X = iris[iris.columns[:-1]]
y = iris[['품종']]
print(X.shape, y.shape)
# Out:
# (150, 4) (150, 1)

# %%
lemonade.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
boston.head()
# Out:
#       crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
iris.head()
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭      품종
# 0   5.1  3.5    1.4   0.2  setosa
# 1   4.9  3.0    1.4   0.2  setosa
# 2   4.7  3.2    1.3   0.2  setosa
# 3   4.6  3.1    1.5   0.2  setosa
# 4   5.0  3.6    1.4   0.2  setosa

# %% [markdown]
# # 레모네이드 판매 예측
# - 레모네이드: https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv

# %%
import tensorflow as tf
import pandas as pd

# %%
dir = "https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv"
df = pd.read_csv(dir)
df.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
X_lemonade = df[['온도']]
y_lemonade = df[['판매량']]
print(X.shape, y.shape)
# Out:
# (None, 1) (None, 1)

# %%
# 모델을 만들자
X = tf.keras.layers.Input(shape=[1])
y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X,y)
model.compile(loss='mse')

# %%
model.fit(X_lemonade, y_lemonade, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0056
# Epoch 2/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0056
# Epoch 3/10
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0056
# Epoch 4/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0056
# Epoch 5/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0056
# Epoch 6/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0056
# Epoch 7/10
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0056
# Epoch 8/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0056
# Epoch 9/10
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0056
# Epoch 10/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0056

# %%
# 모델을 이용
model.predict(X_lemonade)
# Out:
# array([[40.12368 ],
#        [42.081036],
#        [44.038395],
#        [45.995754],
#        [47.95311 ],
#        [49.91047 ]], dtype=float32)

# %% [markdown]
# # 보스턴 집값 예측
# - 보스톤: https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv

# %%
import tensorflow as tf
import pandas as pd

# %%
dir = "https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv"
boston = pd.read_csv(dir)
boston.head()
# Out:
#       crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
X_boston = boston[boston.columns[:-1]]
y_boston = boston[['medv']]
print(X_boston.shape)
print(y_boston.shape)
# Out:
# (506, 13)
# (506, 1)

# %%
X = tf.keras.layers.Input(shape=[13])
y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X,y)
model.compile(loss='mse')

# %%
model.fit(X_boston, y_boston, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 1ms/step - loss: 26.1238
# Epoch 2/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.7185
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.6470
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.6831
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.9348
# Epoch 6/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.3140
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.8850
# Epoch 8/10
# 16/16 [==============================] - 0s 1ms/step - loss: 26.0232
# Epoch 9/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.7826
# Epoch 10/10
# 16/16 [==============================] - 0s 2ms/step - loss: 26.4245

# %%
model.predict(X_boston[0:5])
# Out:
# array([[29.431917],
#        [24.561932],
#        [30.383484],
#        [29.659819],
#        [29.039536]], dtype=float32)

# %%
y_boston[0:5]
# Out:
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
# 모델 수식 확인
model.get_weights()
# Out:
# [array([[-0.08709311],
#         [ 0.06954383],
#         [-0.06069359],
#         [ 3.2572658 ],
#         [ 2.6442602 ],
#         [ 4.1462    ],
#         [ 0.01004779],
#         [-0.90831184],
#         [ 0.15441965],
#         [-0.00987535],
#         [-0.07133251],
#         [ 0.01531838],
#         [-0.56654626]], dtype=float32), array([3.29849], dtype=float32)]

# %% [markdown]
# # Iris 품종 예측
#   - 아이리스: https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv

# %%
import tensorflow as tf
import pandas as pd

# %%
dir = "https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv"
iris = pd.read_csv(dir)
iris.head()
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭      품종
# 0   5.1  3.5    1.4   0.2  setosa
# 1   4.9  3.0    1.4   0.2  setosa
# 2   4.7  3.2    1.3   0.2  setosa
# 3   4.6  3.1    1.5   0.2  setosa
# 4   5.0  3.6    1.4   0.2  setosa

# %%
encoding = pd.get_dummies(iris)
encoding.head()
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭  품종_setosa  품종_versicolor  품종_virginica
# 0   5.1  3.5    1.4   0.2          1              0             0
# 1   4.9  3.0    1.4   0.2          1              0             0
# 2   4.7  3.2    1.3   0.2          1              0             0
# 3   4.6  3.1    1.5   0.2          1              0             0
# 4   5.0  3.6    1.4   0.2          1              0             0

# %%
encoding.columns
# Out:
# Index(['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭', '품종_setosa', '품종_versicolor',
#        '품종_virginica'],
#       dtype='object')

# %%
X_iris = encoding[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
y_iris = encoding[['품종_setosa', '품종_versicolor', '품종_virginica']]
print(X_iris.shape,y_iris.shape)
# Out:
# (150, 4) (150, 3)

# %%
X = tf.keras.layers.Input(shape=[4])
y = tf.keras.layers.Dense(3, activation='softmax')(X)
model = tf.keras.models.Model(X,y)
model.compile(loss='categorical_crossentropy',
              metrics='accuracy')

# %%
model.fit(X_iris, y_iris, epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4001 - accuracy: 0.8933
# Epoch 2/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.9000
# Epoch 3/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3997 - accuracy: 0.8867
# Epoch 4/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3984 - accuracy: 0.9000
# Epoch 5/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3977 - accuracy: 0.9000
# Epoch 6/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3968 - accuracy: 0.9000
# Epoch 7/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3969 - accuracy: 0.9000
# Epoch 8/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.9067
# Epoch 9/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3947 - accuracy: 0.9200
# Epoch 10/100
# ...

# %%
model.predict(X_iris[0:5])
# Out:
# array([[9.9020243e-01, 9.2589520e-03, 5.3860224e-04],
#        [9.7431040e-01, 2.3783667e-02, 1.9059877e-03],
#        [9.8498833e-01, 1.4107658e-02, 9.0406655e-04],
#        [9.7197998e-01, 2.6177742e-02, 1.8423304e-03],
#        [9.9168336e-01, 7.9009170e-03, 4.1566722e-04]], dtype=float32)

# %%
print(y_iris[0:5])
# Out:
#    품종_setosa  품종_versicolor  품종_virginica
# 0          1              0             0
# 1          1              0             0
# 2          1              0             0
# 3          1              0             0
# 4          1              0             0

# %%
model.predict(X_iris[-5:])
# Out:
# array([[2.6218526e-04, 2.9111040e-01, 7.0862740e-01],
#        [2.9575691e-04, 3.2831681e-01, 6.7138743e-01],
#        [4.8919470e-04, 3.6810786e-01, 6.3140297e-01],
#        [4.0996555e-04, 3.7576151e-01, 6.2382847e-01],
#        [8.8007038e-04, 4.5912686e-01, 5.3999305e-01]], dtype=float32)

# %%
print(y_iris[-5:])
# Out:
#      품종_setosa  품종_versicolor  품종_virginica
# 145          0              0             1
# 146          0              0             1
# 147          0              0             1
# 148          0              0             1
# 149          0              0             1

# %%
model.get_weights()
# Out:
# [array([[ 0.01530916, -0.21191025,  0.04813673],
#         [ 1.5946608 , -0.2336272 , -0.9783858 ],
#         [-1.6989043 ,  0.430772  ,  0.6568755 ],
#         [-1.9165978 , -0.46832982,  0.52516925]], dtype=float32),
#  array([ 1.281301  ,  0.89560896, -1.1835887 ], dtype=float32)]

# %% [markdown]
# # Hidden layer

# %% [markdown]
# ## 보스턴 집값 예측

# %%
import tensorflow as tf
import pandas as pd

# %%
dir = "https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv"
boston = pd.read_csv(dir)
boston.head()
# Out:
#       crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
X_boston = boston[boston.columns[:-1]]
y_boston = boston[['medv']]
print(X_boston.shape)
print(y_boston.shape)
# Out:
# (506, 13)
# (506, 1)

# %%
X = tf.keras.layers.Input(shape=[13])
H = tf.keras.layers.Dense(10, activation='swish')(X)
y = tf.keras.layers.Dense(1)(H) # 히든레이어 받는거 잊지 말기
model = tf.keras.models.Model(X,y)
model.compile(loss='mse')

# %%
model.fit(X_boston, y_boston, epochs=1000, verbose=0)
model.fit(X_boston, y_boston, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 2ms/step - loss: 19.7223
# Epoch 2/10
# 16/16 [==============================] - 0s 2ms/step - loss: 20.8332
# Epoch 3/10
# 16/16 [==============================] - 0s 2ms/step - loss: 20.4378
# Epoch 4/10
# 16/16 [==============================] - 0s 2ms/step - loss: 18.6247
# Epoch 5/10
# 16/16 [==============================] - 0s 2ms/step - loss: 21.8274
# Epoch 6/10
# 16/16 [==============================] - 0s 2ms/step - loss: 20.1878
# Epoch 7/10
# 16/16 [==============================] - 0s 2ms/step - loss: 21.0892
# Epoch 8/10
# 16/16 [==============================] - 0s 2ms/step - loss: 19.8580
# Epoch 9/10
# 16/16 [==============================] - 0s 2ms/step - loss: 20.5165
# Epoch 10/10
# 16/16 [==============================] - 0s 2ms/step - loss: 21.2160

# %%
model.summary() # 히든레이어 잘 받았는지 확인
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_11 (InputLayer)        [(None, 13)]              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                140
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 11
# ...
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(model.predict(X_boston[0:5]))
print(y_boston[0:5])
# Out:
# [[30.394758]
#  [25.033627]
#  [30.968355]
#  [30.01804 ]
#  [29.715796]]
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %% [markdown]
# ## 아이리스 품종 분류

# %%
import tensorflow as tf
import pandas as pd

dir = "https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv"
iris = pd.read_csv(dir)

encoding = pd.get_dummies(iris)

X_iris = encoding[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
y_iris = encoding[['품종_setosa', '품종_versicolor', '품종_virginica']]
print(X_iris.shape,y_iris.shape)
# Out:
# (150, 4) (150, 3)

# %%
X = tf.keras.layers.Input(shape=[4])
H = tf.keras.layers.Dense(8, activation='swish')(X)
H = tf.keras.layers.Dense(8, activation='swish')(H)
H = tf.keras.layers.Dense(8, activation='swish')(H)
y = tf.keras.layers.Dense(3, activation='softmax')(H)
model = tf.keras.models.Model(X,y)
model.compile(loss='categorical_crossentropy',
              metrics='accuracy')

# %%
model.fit(X_iris, y_iris, epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9645 - accuracy: 0.7000
# Epoch 2/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9492 - accuracy: 0.7133
# Epoch 3/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9338 - accuracy: 0.7200
# Epoch 4/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.9172 - accuracy: 0.7400
# Epoch 5/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9009 - accuracy: 0.7333
# Epoch 6/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8841 - accuracy: 0.7600
# Epoch 7/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8675 - accuracy: 0.7800
# Epoch 8/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8499 - accuracy: 0.8067
# Epoch 9/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8332 - accuracy: 0.7733
# Epoch 10/100
# ...

# %%
print(model.predict(X_iris[0:5]))
print(y_iris[0:5])
# Out:
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0762bea950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[9.9909508e-01 9.0492133e-04 1.5472041e-08]
#  [9.9698430e-01 3.0157540e-03 2.7473847e-08]
#  [9.9672592e-01 3.2739530e-03 8.8708504e-08]
#  [9.9242204e-01 7.5777490e-03 2.0922762e-07]
#  [9.9894923e-01 1.0508213e-03 3.3275793e-08]]
# ...

# %%
print(model.predict(X_iris[-5:]))
print(y_iris[-5:])
# Out:
# [[1.6745122e-04 6.3853435e-02 9.3597913e-01]
#  [3.4399968e-04 1.1825018e-01 8.8140583e-01]
#  [3.4532335e-04 1.1256545e-01 8.8708919e-01]
#  [4.8068152e-05 2.5296699e-02 9.7465521e-01]
#  [2.5864260e-04 9.1820411e-02 9.0792102e-01]]
#      품종_setosa  품종_versicolor  품종_virginica
# 145          0              0             1
# 146          0              0             1
# 147          0              0             1
# 148          0              0             1
# 149          0              0             1

# %% [markdown]
# # 데이터 타입 조정
# https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris2.csv
#
# - 변수(칼럼) 타입 확인: 데이터.dtypes
# - 변수를 범주형으로 변경:
#   - 데이터['칼럼명'].astype('category')
# - 변수를 수치형으로 변경:
#   - 데이터['칼럼명'].astype('int')
#   - 데이터['칼럼명'].astype('float')
# - NA 값의 처리
#   - NA 갯수 체크: 데이터.isna().sum()
#   - NA 값 채우기: 데이터['칼럼명'].fillna(특정숫자)

# %%
import pandas as pd

# %%
dir = "https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris2.csv"
iris = pd.read_csv(dir)
iris.head()
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭  품종
# 0   5.1  3.5    1.4   0.2   0
# 1   4.9  3.0    1.4   0.2   0
# 2   4.7  3.2    1.3   0.2   0
# 3   4.6  3.1    1.5   0.2   0
# 4   5.0  3.6    1.4   0.2   0

# %%
# 원핫인코딩
encoding = pd.get_dummies(iris)
encoding.head()
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭  품종
# 0   5.1  3.5    1.4   0.2   0
# 1   4.9  3.0    1.4   0.2   0
# 2   4.7  3.2    1.3   0.2   0
# 3   4.6  3.1    1.5   0.2   0
# 4   5.0  3.6    1.4   0.2   0

# %%
iris.dtypes
# Out:
# 꽃잎길이     float64
# 꽃잎폭      float64
# 꽃받침길이    float64
# 꽃받침폭     float64
# 품종         int64
# dtype: object

# %%
# 품종 데이터 타입을 범주형으로 바꾸어 준다
iris['품종'] = iris['품종'].astype('category')
print(iris.dtypes)
# Out:
# 꽃잎길이      float64
# 꽃잎폭       float64
# 꽃받침길이     float64
# 꽃받침폭      float64
# 품종       category
# dtype: object

# %%
# 다시 원핫인코딩을 한다
encoding = pd.get_dummies(iris)
encoding.head()
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭  품종_0  품종_1  품종_2
# 0   5.1  3.5    1.4   0.2     1     0     0
# 1   4.9  3.0    1.4   0.2     1     0     0
# 2   4.7  3.2    1.3   0.2     1     0     0
# 3   4.6  3.1    1.5   0.2     1     0     0
# 4   5.0  3.6    1.4   0.2     1     0     0

# %%
# NA값 체크
iris.isna().sum()
# Out:
# 꽃잎길이     0
# 꽃잎폭      1
# 꽃받침길이    0
# 꽃받침폭     0
# 품종       0
# dtype: int64

# %%
iris.tail()
# Out:
#      꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭 품종
# 145   6.7  3.0    5.2   2.3  2
# 146   6.3  2.5    5.0   1.9  2
# 147   6.5  3.0    5.2   2.0  2
# 148   6.2  3.4    5.4   2.3  2
# 149   5.9  NaN    5.1   1.8  2

# %%
# NA값에 꽃잎폭 평균값을 넣어주기
mean = iris['꽃잎폭'].mean()
iris['꽃잎폭'] = iris['꽃잎폭'].fillna(mean)
iris.tail()

# 채우지 말고 drop도 방법...!
# Out:
#      꽃잎길이       꽃잎폭  꽃받침길이  꽃받침폭 품종
# 145   6.7  3.000000    5.2   2.3  2
# 146   6.3  2.500000    5.0   1.9  2
# 147   6.5  3.000000    5.2   2.0  2
# 148   6.2  3.400000    5.4   2.3  2
# 149   5.9  3.054362    5.1   1.8  2

# %% [markdown]
# # 학습이 잘 되는 모델
#
# - 사용할 레이어
#   - tf.keras.layers.BatchNormalization()
#   - tf.keras.layers.Activation('swish')
#
# - 데이터
#   - 보스턴 집값 예측: https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv
#   - 아이리스 품종 분류: https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv

# %%
# 라이브러리 사용 
import tensorflow as tf
import pandas as pd

# %%
# 1.과거의 데이터를 준비합니다.
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
보스턴 = pd.read_csv(파일경로)

# 종속변수, 독립변수
독립 = 보스턴[['crim', 'zn', 'indus', 'chas', 'nox', 
            'rm', 'age', 'dis', 'rad', 'tax',
            'ptratio', 'b', 'lstat']]
종속 = 보스턴[['medv']]
print(독립.shape, 종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
# 2. 모델의 구조를 만듭니다
X = tf.keras.layers.Input(shape=[13])
H = tf.keras.layers.Dense(8, activation='swish')(X)
H = tf.keras.layers.Dense(8, activation='swish')(H)
H = tf.keras.layers.Dense(8, activation='swish')(H)
Y = tf.keras.layers.Dense(1)(H)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %%
model.fit(독립, 종속, epochs=1000)
# Out:
# Epoch 1/1000
# 16/16 [==============================] - 1s 2ms/step - loss: 439.8200
# Epoch 2/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 249.5212
# Epoch 3/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 150.8817
# Epoch 4/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 102.0334
# Epoch 5/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 84.2292
# Epoch 6/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 80.0044
# Epoch 7/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 75.4553
# Epoch 8/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 71.5156
# Epoch 9/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 68.4823
# Epoch 10/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 65.1164
# Epoch 11/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 65.2322
# Epoch 12/1000
# ...

# %%
# 2. 모델의 구조를 BatchNormalization layer를 사용하여 만든다.
X = tf.keras.layers.Input(shape=[13])

H = tf.keras.layers.Dense(8)(X)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H) # 배치노멀리제이션을 하기 위해 활성화함수 갈라줌

H = tf.keras.layers.Dense(8)(H)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

H = tf.keras.layers.Dense(8)(H)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

Y = tf.keras.layers.Dense(1)(H)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %%
model.fit(독립, 종속, epochs=1000)
# Out:
# Epoch 1/1000
# 16/16 [==============================] - 1s 2ms/step - loss: 574.2933
# Epoch 2/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 564.4630
# Epoch 3/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 556.7632
# Epoch 4/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 549.8580
# Epoch 5/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 543.1832
# Epoch 6/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 535.9075
# Epoch 7/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 528.7609
# Epoch 8/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 522.0784
# Epoch 9/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 515.0828
# Epoch 10/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 508.7232
# Epoch 11/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 500.3807
# Epoch 12/1000
# ...

# %% [markdown]
# 분류 모델에서도 해보자

# %%
# 1.과거의 데이터를 준비합니다.
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv'
아이리스 = pd.read_csv(파일경로)

# 원핫인코딩
아이리스 = pd.get_dummies(아이리스)

# 종속변수, 독립변수
독립 = 아이리스[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
종속 = 아이리스[['품종_setosa', '품종_versicolor', '품종_virginica']]
print(독립.shape, 종속.shape)
# Out:
# (150, 4) (150, 3)

# %%
# 2. 모델의 구조를 만듭니다
X = tf.keras.layers.Input(shape=[4])

H = tf.keras.layers.Dense(8)(X)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

H = tf.keras.layers.Dense(8)(H)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

H = tf.keras.layers.Dense(8)(H)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

Y = tf.keras.layers.Dense(3, activation='softmax')(H)
model = tf.keras.models.Model(X, Y)
model.compile(loss='categorical_crossentropy',
              metrics='accuracy')

# %%
model.fit(독립, 종속, epochs=1000, batch_size=150)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 1s/step - loss: 1.4468 - accuracy: 0.0800
# Epoch 2/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3635 - accuracy: 0.0867
# Epoch 3/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3032 - accuracy: 0.1067
# Epoch 4/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2555 - accuracy: 0.1267
# Epoch 5/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2158 - accuracy: 0.1400
# Epoch 6/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1814 - accuracy: 0.1533
# Epoch 7/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1506 - accuracy: 0.1600
# Epoch 8/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1226 - accuracy: 0.1667
# Epoch 9/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0966 - accuracy: 0.1933
# Epoch 10/1000
# ...
