# %% [markdown]
# strip() 공백 제거 함수

# %%
st="\tHello, world! \t\t\n" # 모든 줄 바꿈과 탭 (\n, \t, \t)
st
# Out:
# '\tHello, world! \t\t\n'

# %%
st.strip() # 모든 공백 제거
# Out:
# 'Hello, world!'

# %%
st.lstrip() # 왼쪽 공백 제거
# Out:
# 'Hello, world! \t\t\n'

# %%
st.rstrip() # 오른쪽 공백 제거
# Out:
# '\tHello, world!'

# %% [markdown]
# split(delim="") 문자열 자르기 함수

# %%
"Hello, world!".split() # # delim 구분자 -< default 공백
# Out:
# ['Hello,', 'world!']

# %%
"Hello, world!".split(",") # 구분자 -> ,(콤마)
# Out:
# ['Hello', ' world!']

# %%
"www.networksciencelab.com".split(".")
# Out:
# ['www', 'networksciencelab', 'com']

# %% [markdown]
# join(Is) 문자열을 연결시키는 함수

# %%
" ".join(["alpha", "bravo", "charlie", "delta"]) # 문자열 리스트 is 하나의 문자열로 붙임 -> 문자열 조각을 재조합
# Out:
# 'alpha bravo charlie delta'

# %%
"-".join("1.617.305.1985".split("."))
# Out:
# '1-617-305-1985'

# %%
# 1) . 구분자로 자른다
Is = "1.617.305.1985".split(".")
# 2) Is를 - 구분자로 붙인다.
"-".join(Is)
# Out:
# '1-617-305-1985'

# %%
# "This string\n\r.has many\t\tspaces".split()
" ".join("This string\n\r.has many\t\tspaces".split())
# Out:
# 'This string .has many spaces'

# %%
# 1) \n\r 공백 데이터 기준으로 자르기
ls = "This string\n\r has many\t\tspaces"
ls
# 2) 공백 한칸으로 재조합
# " ".join(Is)
# Out:
# 'This string\n\r has many\t\tspaces'

# %%
" ".join("This string\n\r has many\t\tspaces".split())
# Out:
# 'This string has many spaces'

# %% [markdown]
# find(needle) 해당 문자열에 부문 문자열 needle 처음 등장하는 인덱스 반환(위치) 없으면 -1 반환하는 함수 (대소문자 구분)

# %%
"www.networksciencelab.com".find(".com")
# Out:
# 21

# %% [markdown]
# count(needle) 해당 문자열에서 등장하는 횟수를 반환하는 함수 (대소문자 구분)

# %%
"www.networksciencelab.com".count(".com")
# Out:
# 1

# %%
"www.networksciencelab.com".count('w')
# Out:
# 4

# %%
"www.networksciencelab.com".count("C")
# Out:
# 0

# %% [markdown]
# 프레디케이트 함수 -> 문자열 s가 특정 클래스에 속하는지 True, False로 반환

# %%
"www.networksciencelab.com".islower() # 모든 알파벳 문자가 소문자인지 체크
# Out:
# True

# %%
"www.networksciencelab.com".isupper() # 모든 알파벳 문자가 대문자인지 체크
# Out:
# False

# %%
"www.networksciencelab.com".isdigit() # 0~9 사이 숫자인지 확인
# Out:
# False

# %%
"wwwnetworksciencelabcom".isalpha() # dot(.) 제거 해야 만 True -> 알파벳(숫자, 특수기호 x) 인지 체크
# Out:
# True

# %% [markdown]
# 대.소문자 변환 함수 -> 모든 문자 대.소문자 변환 (문자열 s의 복사본 반환)

# %%
st= "www.networksciencelab.com".upper()
st
# Out:
# 'WWW.NETWORKSCIENCELAB.COM'

# %%
st.lower()
# Out:
# 'www.networksciencelab.com'

# %%
st
# Out:
# 'WWW.NETWORKSCIENCELAB.COM'

# %%
st = st.lower()

# %%
st
# Out:
# 'www.networksciencelab.com'

# %% [markdown]
# 2. 올바른 자료구조 선택하기

# %% [markdown]
# 중복된 아이템이 있는 리스트 -> mylist

# %%
myList = "This string\n\r has many\t\tspaces\tThis string\n\r has many\t\tspaces".split()
myList
# Out:
# ['This',
#  'string',
#  'has',
#  'many',
#  'spaces',
#  'This',
#  'string',
#  'has',
#  'many',
#  'spaces']

# %% [markdown]
# 리스트 -> 셋 변환 -> 다시 리스트로 변환

# %%
# 1) set 변환 (중복 제거)
print(set(myList))
# 2) 중복 제거한 데이터를 리스트로 변환
myList = list(set(myList))
print(myList)
# Out:
# {'has', 'many', 'This', 'string', 'spaces'}
# ['has', 'many', 'This', 'string', 'spaces']

# %%
myList
# Out:
# ['This', 'string', 'spaces', 'has', 'many']

# %% [markdown]
# 리스트 vs 셋 회원 명단 조회하기

# %%
bigList = [str(i) for i in range(10000000)] # 리스트 내포 (안에서 for문 돌리는 방법)
"abc" in bigList # bigList 리스트에 abc 데이터 IN(포함) 되어 있는지 확인
# Out:
# False

# %%
bigList = set(bigList) # 셋으로 변환 하면 중복 제거 되기 때문에 데이터 조회 시 빠름
"abc" in bigList #0초 걸림
# Out:
# False

# %% [markdown]
# 딕셔너리 (키-값으로 검색해야할 때 매우 유용)

# %%
# 1) 리스트 준비
seq = ["alpha", "bravo", "charlie", "delta"]

# 2) 딕셔너리 만들기 -> 인덱스 정보를 key, Data를 value
dict(enumerate(seq))
# Out:
# {0: 'alpha', 1: 'bravo', 2: 'charlie', 3: 'delta'}

# %% [markdown]
# 리스트 딕셔너리 만들기 - 키순서열과 값 순서열에 클래스 생성자인 zip(key, value) 사용

# %%
kseq = "abcd" #문자열 또한, 숫자열이다.
vseq = ["alpha", "bravo", "charlie", "delta"]

dict(zip(kseq, vseq))
# Out:
# {'a': 'alpha', 'b': 'bravo', 'c': 'charlie', 'd': 'delta'}

# %%
# key는 중복되면 안 됨!
kseq = "aaaa"
vseq = ["alpha", "bravo", "charlie", "delta"]

dict(zip(kseq, vseq))
# Out:
# {'a': 'delta'}

# %% [markdown]
# 카운터(counter)는 딕셔너리 스타일의 컬렉션에서 다른 컬렉션 안의 아이템 개수 셀 때 사용

# %%
from collections import Counter

phrase = "a plan a man a canal panama"
ls=phrase.split()
ls
# Out:
# ['a', 'plan', 'a', 'man', 'a', 'canal', 'panama']

# %%
cntr = Counter(ls)
cntr.most_common() # 가장 빈번하게 등장한 n개의 아이템과 빈도 추출 -> dictionary 아니고
# Out:
# [('a', 3), ('plan', 1), ('man', 1), ('canal', 1), ('panama', 1)]

# %%
cntrDict = dict(cntr.most_common()) # key : 추출된 아이템, value : 아이템 빈도
cntrDict
# Out:
# {'a': 3, 'canal': 1, 'man': 1, 'panama': 1, 'plan': 1}

# %%
cntrDict['plan']
# Out:
# 1

# %% [markdown]
# 웹에 접근하기

# %%
import urllib.request

try:
  with urllib.urlopen("www.networksciencelab.com") as doc:
    html = doc.read()
    print(html)

except:
  print("Could not open ")
# Out:
# Could not open

# %%
import urllib.request
    
with urllib.urlopen("www.networksciencelab.com") as doc:
    html = doc.read()
    print(html)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-5d446841a4c5> in <module>()
#       1 import urllib.request
#       2
# ----> 3 with urllib.urlopen("www.networksciencelab.com") as doc:
#       4     html = doc.read()
#       5     print(html)
#
# AttributeError: module 'urllib' has no attribute 'urlopen'

# %%
import urllib.parse

URL = "http://networksciencelab.com/index.html;param?foo=bar#content" # url 파싱하여 6개의 아이템으로 구성된 튜플로 분리 스키마 네트워크 주소, 파일 시스템 경로, 파라미터, 쿼리, 플래그먼트
urllib.parse.urlparse(URL)
# Out:
# ParseResult(scheme='http', netloc='networksciencelab.com', path='/index.html', params='param', query='foo=bar', fragment='content')

# %% [markdown]
# 정규식

# %%
a = 'abcdef\n'
print(a)

b=r'abcdef\n' #원천 문자열(raw string) 로 인식
print(b)
# Out:
# abcdef
#
# abcdef\n

# %%
import re
 
text = "문의사항이 있으면 032-232-3245 으로 연락주시기 바랍니다."
 
regex = re.compile(r'\d\d\d-\d\d\d-\d\d\d\d')
matchobj = regex.search(text)
print(matchobj)
phonenumber = matchobj.group()
print(phonenumber)
# Out:
# <re.Match object; span=(10, 22), match='032-232-3245'>
# 032-232-3245

# %%
import re

re.compile(r'(\d+)/(\d+)/(\d+)') # raw string -> 0/0/0 1/1/1 3/3/3
# Out:
# re.compile(r'(\d+)/(\d+)/(\d+)', re.UNICODE)

# %%
re.compile('(\\d+)/(\\d+)/(\\d+)') # raw string 사용하지 않으면, 슬래시를 두 번 사용해야 하는 불편함 -> 그래서 보통 r문자를 붙여줌
# Out:
# re.compile(r'(\d+)/(\d+)/(\d+)', re.UNICODE)

# %% [markdown]
# **정규 표현식으로 패턴 매칭하기
#
# re.split()함수 단어 분석을 위한 기본적인 단어 토크나이저로 사용할 수 있음**

# %%
import re

re.split(r"\W", "Hello, world!") # r"\W" -> 숫자, 알파벳 제외한 개체 1개 -> 잘라라
# Out:
# ['Hello', '', 'world', '']

# %%
# 인근에 위치한 비문자(non-letter) (,)를 합친다.
re.split(r"\W+", "Hello, world!") # r"\W+" 알파벳이나 숫자가 아닌 객체 1개 이상 합친다(+)
# Out:
# ['Hello', 'world', '']

# %%
mo = re.match(r"\d+", "067 Starts with a number")
mo
# Out:
# <re.Match object; span=(0, 3), match='067'>

# %%
mo.group()
# Out:
# '067'

# %%
print(re.match(r"\d+","Does not Starts with a number")) # match 첫 번째 문장에 숫자가 있는지 없는지 찾음
# Out:
# None

# %%
# search 문자열 일부분이 정규식과 매치되는지 확인(매칭되는게 앞부분에 없다면 이 함수 사용)
# [a-z] : 소문자들만 일치
# re.I : 대소문자 구분 하지 않음
re.search(r"[a-z]+", "0010010 Has at least one 010 letter 0010010",re.I).group()
# Out:
# 'Has'

# %%
# search 문자열 일부분이 정규식과 매치되는지 확인(매칭되는게 앞부분에 없다면 이 함수 사용)
# [a-z] : 소문자들만 일치
# re.I : 대소문자 구분 하지 않음
re.search(r"[a-z]+", "0010010 Has at least one 010 letter 0010010").group()
# Out:
# 'as'

# %%
# search 문자열 일부분이 정규식과 매치되는지 확인(매칭되는게 앞부분에 없다면 이 함수 사용)
# [A-Z] : 소문자들만 일치
# re.I : 대소문자 구분 하지 않음
re.search(r"[A-Z]+", "0010010 has at least ONE 010 letter 0010010")
# Out:
# <re.Match object; span=(21, 24), match='ONE'>

# %%
# findall : 정규식에 부합하는 모든 문자열 찾기(대소문자 무시) -> 모든 소문자 들어 있는 토큰 찾기
re.findall(r"[a-z]+", "0010010 Has at least one 010 letter 0010010",re.I)
# Out:
# ['Has', 'at', 'least', 'one', 'letter']

# %%
# findall : 정규식에 부합하는 모든 문자열 찾기(대소문자 무시) -> 모든 소문자 들어 있는 토큰 찾기
re.findall(r"[a-z]+", "0010010 Has at least one 010 letter 0010010")
# Out:
# ['as', 'at', 'least', 'one', 'letter']

# %%
# findall : 정규식에 부합하는 모든 문자열 찾기(대소문자 무시) -> 모든 소문자 들어 있는 토큰 찾기
re.findall(r"\d+", "0010010 Has at least one 010 letter 0010010")
# Out:
# ['0010010', '010', '0010010']

# %%
# findall : 정규식에 부합하는 모든 문자열 찾기(대소문자 무시) -> 모든 소문자 들어 있는 토큰 찾기
re.findall(r"\D+", "0010010 Has at least one 010 letter 0010010")
# Out:
# [' Has at least one ', ' letter ']

# %%
# findall : 정규식에 부합하는 모든 문자열 찾기(대소문자 무시) -> 모든 소문자 들어 있는 토큰 찾기
re.findall(r"[^a-z]+", "0010010 Has at least one 010 letter 0010010")
# Out:
# ['0010010 H', ' ', ' ', ' ', ' 010 ', ' 0010010']

# %%
# sub: string으로 매칭되는 부분 문자열을 repl로 치환
re.sub(r"[a-z]+",'[...]', "0010010 Has at least one 010 letter 0010010",flags=re.I)
# Out:
# '0010010 [...] [...] [...] [...] 010 [...] 0010010'

# %%
#010-abcd-0100 -> abcd 값을 **** 으로 치환
re.sub(r"[a-z]+", "****", "010-abcd-0100")
# Out:
# '010-****-0100'

# %%
#010-abcd-0100 -> abcd 값을 **** 으로 치환
re.sub(r"\W+", "****", "010-abcd-0100")
# Out:
# '010****abcd****0100'

# %%
#010-abcd-0100 -> 숫자 값을 **** 으로 치환
re.sub(r"\D+","****","010-abcd-0100")
# Out:
# '010****0100'

# %%
#010-abcd-0100 -> 숫자 값을 **** 으로 치환
re.sub(r"[0-9]+","****","010-abcd-0100")
# Out:
# '****-abcd-****'
