# %% [markdown]
# ### 1) 성별 데이터 수평 막대 스래프로 시각화

# %%
import matplotlib.pyplot as plt
import csv
f1 = open('gender.csv', encoding = 'cp949')
data = csv.reader(f1)

m=[]
f=[]

for row in data:
  if '보람동' in row[0]:
    for i in range(0,101):
      m.append(-int(row[i+3]))
      f.append(int(row[-(i+1)]))
      # -1 값부터 담음 -> 100세 이상 부터 값이 담김


f.reverse()
plt.figure(dpi=200)
plt.rc('font', family = 'NanumBarunGothic') # 나눔 바른 고딕을 기본 글꼴로 설정
plt.rcParams['axes.unicode_minus'] = False # 마이너스 기호 깨짐 방지
plt.style.use('ggplot') #격자 무늬 스타일로 지정

plt.barh(range(101), m, color= 'steelblue', label='남자')
plt.barh(range(101), f, color= 'tomato', label='여자')
plt.title('세종시 보람동의 남녀 성별 인구 분포')

plt.legend()
plt.show()
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46988 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 39 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 160772 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %% [markdown]
# ### 2) 2019년 2월 vs 2020년 2월 연령별 인구 구조 비교

# %%
import matplotlib.pyplot as plt
import csv
f2 = open('2008.csv', encoding = 'cp949')
data2 = csv.reader(f2)
f3 = open('2021.csv', encoding = 'cp949')
data3 = csv.reader(f3)
f4 = open('2018.csv', encoding = 'cp949')
data4 = csv.reader(f4)
f5 = open('2020_age.csv', encoding = 'cp949')
data5 = csv.reader(f5)

result_data2=[]
result_data3=[]
result_data4=[]
result_data5=[]



for row in data2:
  if '충청남도 연기군 금남면' in row[0]:
    for i in row[3:]:
      result_data2.append(int(i.replace(',',''))) #인구 수 데이터 정수로 반환 후 result 변수에 담기

for row in data3:
  if '보람동' in row[0]:
    for i in row[3:]:
      result_data3.append(int(i.replace(',',''))) #인구 수 데이터 정수로 반환 후 result 변수에 담기

for row in data4:
  if '보람동' in row[0]:
    for i in row[3:]:
      result_data4.append(int(i.replace(',',''))) #인구 수 데이터 정수로 반환 후 result 변수에 담기

for row in data5:
  if '보람동' in row[0]:
    for i in row[3:]:
      result_data5.append(int(i.replace(',',''))) #인구 수 데이터 정수로 반환 후 result 변수에 담기





plt.figure(dpi=200)
plt.style.use('ggplot')
plt.rc('font', family='NanumBarunGothic') 
plt.plot(result_data2 , label='2008')
plt.plot(result_data4 , color='lightgreen', label='2018')
plt.plot(result_data5 , label='2020')
plt.plot(result_data3 , label='2021')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-16e9d416f5d3> in <module>()
#       5 f3 = open('2021.csv', encoding = 'cp949')
#       6 data3 = csv.reader(f3)
# ----> 7 f4 = open('2018.csv', encoding = 'cp949')
#       8 data4 = csv.reader(f4)
#       9 f5 = open('2020_age.csv', encoding = 'cp949')
#
# FileNotFoundError: [Errno 2] No such file or directory: '2018.csv'

# %%
import matplotlib.pyplot as plt
import csv
f1 = open('2008.csv', encoding = 'cp949')
data1 = csv.reader(f1)
f2 = open('2021.csv', encoding = 'cp949')
data2 = csv.reader(f2)
f3 = open('2012.csv', encoding = 'cp949')
data3 = csv.reader(f3)

result_data1=[]
result_data2=[]
result_data3=[]




for row in data1:
  if '야탑1동' in row[0]:
    for i in row[3:]:
      result_data1.append(int(i.replace(',',''))) #인구 수 데이터 정수로 반환 후 result 변수에 담기

for row in data2:
  if '야탑1동' in row[0]:
    for i in row[3:]:
      result_data2.append(int(i.replace(',',''))) #인구 수 데이터 정수로 반환 후 result 변수에 담기

for row in data3:
  if '야탑1동' in row[0]:
    for i in row[3:]:
      result_data3.append(int(i.replace(',',''))) #인구 수 데이터 정수로 반환 후 result 변수에 담기


plt.figure(dpi=200)
plt.style.use('ggplot')
plt.rc('font', family='NanumBarunGothic') 
plt.title('야탑1동 인구 분포')
plt.plot(result_data1 , label='2008')
plt.plot(result_data2 , label='2012')
plt.plot(result_data3 , label='2021')
plt.legend()
plt.show()
